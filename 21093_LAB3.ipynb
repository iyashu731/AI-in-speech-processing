# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import librosa.display
from IPython.display import Audio
import IPython.display as ipd
import numpy as np

# %% [markdown]
# # A 1

# %%
y, sr = librosa.load('speechlearning.wav')
librosa.display.waveshow(y)
plt.title('Speech Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# # plotting

# %%
import librosa
import matplotlib.pyplot as plt

# Load the audio file
audio, sample_rate = librosa.load('speechlearning.wav')

# Display the original speech signal 
plt.figure(figsize=(10, 4))
librosa.display.waveshow(audio, sr=sample_rate, color='blue')
plt.title('Original Speech Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# # Trim the silent parts from the beginning and end of the signal and plot the trimmed signal

# %%
y_trimmed_audio,index= librosa.effects.trim(y)

# Display the original speech signal 
plt.figure(figsize=(10, 4))
librosa.display.waveshow(y_trimmed_audio, sr=sample_rate, color='green')
plt.title('Trimmed Speech Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# # comparing

# %%
import IPython.display as ipd

print("Trimmed Speech Signal")
ipd.Audio(data=y_trimmed_audio,rate=sample_rate)
# Out:
# Trimmed Speech Signal
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original Speech Signal")
ipd.Audio(data=audio,rate=sample_rate)
# Out:
# Original Speech Signal
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # A2

# %%
import librosa
from IPython.display import Audio, display

y, sr = librosa.load('speechlearning.wav')

segments = librosa.effects.split(y, top_db=20)  # Adjust top_db as needed

for i, segment in enumerate(segments):
    # Only process segments 1 through 4
    if i < 4:
        start, end = segment
        segment_audio = y[start:end]

        print(f"Playing Segment {i+1}: Duration {len(segment_audio)/sr} seconds")
        display(Audio(segment_audio, rate=sr))
# Out:
# Playing Segment 1: Duration 0.18575963718820862 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Playing Segment 2: Duration 1.18421768707483 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Playing Segment 3: Duration 0.25541950113378686 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Playing Segment 4: Duration 0.5804988662131519 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
